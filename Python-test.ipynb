# %% [markdown]
# # Python test

# %% [markdown]
# ## 1. Import and clean the data

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### 1.1. Drugs file

# %%
drugs_df = pd.read_csv("drugs.csv")

# %%
drugs_df
# Out:
#    atccode             drug
# 0    A04AD  DIPHENHYDRAMINE
# 1    S03AA     TETRACYCLINE
# 2    V03AB          ETHANOL
# 3    A03BA         ATROPINE
# 4    A01AD      EPINEPHRINE
# 5  6302001     ISOPRENALINE
# 6    R01AD    BETAMETHASONE

# %% [markdown]
# ### 1.2. Pubmed files

# %%
pubmed_df = pd.read_csv("pubmed.csv")

# %%
pubmed_df
# Out:
#    id                                              title        date  \
# 0   1  A 44-year-old man with erythema of the face di...  01/01/2019
# 1   2  An evaluation of benadryl, pyribenzamine, and ...  01/01/2019
# 2   3  Diphenhydramine hydrochloride helps symptoms o...  02/01/2019
# 3   4  Tetracycline Resistance Patterns of Lactobacil...  01/01/2020
# 4   5  Appositional Tetracycline bone formation rates...  02/01/2020
# 5   6  Rapid reacquisition of contextual fear followi...  2020-01-01
# 6   7  The High Cost of Epinephrine Autoinjectors and...  01/02/2020
# 7   8  Time to epinephrine treatment is associated wi...  01/03/2020
#
#                                              journal
# 0                       Journal of emergency nursing
# 1                       Journal of emergency nursing
# 2                          The Journal of pediatrics
# 3                         Journal of food protection
# 4            American journal of veterinary research
# 5                                 Psychopharmacology
# 6  The journal of allergy and clinical immunology...
# 7  The journal of allergy and clinical immunology...

# %%
pubmed_df['date'] = pd.to_datetime(pubmed_df['date'])

# %%
pubmed_df
# Out:
#    id                                              title       date  \
# 0   1  A 44-year-old man with erythema of the face di... 2019-01-01
# 1   2  An evaluation of benadryl, pyribenzamine, and ... 2019-01-01
# 2   3  Diphenhydramine hydrochloride helps symptoms o... 2019-02-01
# 3   4  Tetracycline Resistance Patterns of Lactobacil... 2020-01-01
# 4   5  Appositional Tetracycline bone formation rates... 2020-02-01
# 5   6  Rapid reacquisition of contextual fear followi... 2020-01-01
# 6   7  The High Cost of Epinephrine Autoinjectors and... 2020-01-02
# 7   8  Time to epinephrine treatment is associated wi... 2020-01-03
#
#                                              journal
# 0                       Journal of emergency nursing
# 1                       Journal of emergency nursing
# 2                          The Journal of pediatrics
# 3                         Journal of food protection
# 4            American journal of veterinary research
# 5                                 Psychopharmacology
# 6  The journal of allergy and clinical immunology...
# 7  The journal of allergy and clinical immunology...

# %%
pubmed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       8 non-null      int64
#  1   title    8 non-null      object
#  2   date     8 non-null      datetime64[ns]
#  3   journal  8 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 384.0+ bytes

# %% [markdown]
# ---

# %%
pubmed_json = pd.read_json("pubmed.json", orient='records')

# %%
pubmed_json
# Out:
#    id                                              title       date  \
# 0   9  Gold nanoparticles synthesized from Euphorbia ... 2020-01-01
# 1  10  Clinical implications of umbilical artery Dopp... 2020-01-01
# 2  11  Effects of Topical Application of Betamethason... 2020-01-01
# 3  12  Comparison of pressure release, phonophoresis ... 2020-01-03
# 4  13  Comparison of pressure BETAMETHASONE release, ... 2020-01-03
#
#                                              journal
# 0  Journal of photochemistry and photobiology. B,...
# 1  The journal of maternal-fetal & neonatal medicine
# 2  Journal of back and musculoskeletal rehabilita...
# 3  Journal of back and musculoskeletal rehabilita...
# 4  The journal of maternal-fetal & neonatal medicine

# %%
pubmed_json['date'] = pd.to_datetime(pubmed_json['date'])

# %%
pubmed_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       5 non-null      int64
#  1   title    5 non-null      object
#  2   date     5 non-null      datetime64[ns]
#  3   journal  5 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# ---

# %%
pubmed_final_df = pubmed_df.append(pubmed_json).reset_index(drop=True)

# %%
pubmed_final_df
# Out:
#     id                                              title       date  \
# 0    1  A 44-year-old man with erythema of the face di... 2019-01-01
# 1    2  An evaluation of benadryl, pyribenzamine, and ... 2019-01-01
# 2    3  Diphenhydramine hydrochloride helps symptoms o... 2019-02-01
# 3    4  Tetracycline Resistance Patterns of Lactobacil... 2020-01-01
# 4    5  Appositional Tetracycline bone formation rates... 2020-02-01
# 5    6  Rapid reacquisition of contextual fear followi... 2020-01-01
# 6    7  The High Cost of Epinephrine Autoinjectors and... 2020-01-02
# 7    8  Time to epinephrine treatment is associated wi... 2020-01-03
# 8    9  Gold nanoparticles synthesized from Euphorbia ... 2020-01-01
# 9   10  Clinical implications of umbilical artery Dopp... 2020-01-01
# 10  11  Effects of Topical Application of Betamethason... 2020-01-01
# 11  12  Comparison of pressure release, phonophoresis ... 2020-01-03
# 12  13  Comparison of pressure BETAMETHASONE release, ... 2020-01-03
#
#                                               journal
# 0                        Journal of emergency nursing
# 1                        Journal of emergency nursing
# 2                           The Journal of pediatrics
# 3                          Journal of food protection
# 4             American journal of veterinary research
# 5                                  Psychopharmacology
# 6   The journal of allergy and clinical immunology...
# 7   The journal of allergy and clinical immunology...
# 8   Journal of photochemistry and photobiology. B,...
# 9   The journal of maternal-fetal & neonatal medicine
# 10  Journal of back and musculoskeletal rehabilita...
# 11  Journal of back and musculoskeletal rehabilita...
# 12  The journal of maternal-fetal & neonatal medicine

# %%
# retour vers des dates en string pour une meilleure lisibilité
pubmed_final_df['date'] = pubmed_final_df['date'].dt.strftime('%Y-%m-%d')

# %% [markdown]
# ### 1.3. Clinical trials file

# %%
clinical_trials_df = pd.read_csv("clinical_trials.csv")

# %%
clinical_trials_df['date'] = pd.to_datetime(clinical_trials_df['date'])

# %%
clinical_trials_df
# Out:
#             id                                   scientific_title       date  \
# 0  NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati... 2020-01-01
# 1  NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch... 2020-01-01
# 2  NCT04237090                                                    2020-01-01
# 3  NCT04237091  Feasibility of a Randomized Controlled Clinica... 2020-01-01
# 4  NCT04153396  Preemptive Infiltration With Betamethasone and... 2020-01-01
# 5  NCT03490942  Glucagon Infusion in T1D Patients With Recurre... 2020-05-25
# 6          NaN  Glucagon Infusion in T1D Patients With Recurre... 2020-05-25
# 7  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl... 2020-04-27
#
#                                 journal
# 0          Journal of emergency nursing
# 1          Journal of emergency nursing
# 2          Journal of emergency nursing
# 3          Journal of emergency nursing
# 4     Hôpitaux Universitaires de Genève
# 5                                   NaN
# 6          Journal of emergency nursing
# 7  Journal of emergency nursing\xc3\x28

# %%
clinical_trials_final_df = clinical_trials_df.fillna('')\
    .groupby('scientific_title', as_index=False)\
    .max().replace(r'^\s*$', np.nan, regex=True)\
    .dropna()

# on replace les NaN par un str vide pour regrouper les titres en double
# on replace les string contenant des espaces pour enlever les lignes dont le titre est vide

# %%
clinical_trials_final_df
# Out:
#                                     scientific_title           id       date  \
# 1  Feasibility of a Randomized Controlled Clinica...  NCT04237091 2020-01-01
# 2  Glucagon Infusion in T1D Patients With Recurre...  NCT03490942 2020-05-25
# 3  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...  NCT04189588 2020-01-01
# 4  Preemptive Infiltration With Betamethasone and...  NCT04153396 2020-01-01
# 5  Tranexamic Acid Versus Epinephrine During Expl...  NCT04188184 2020-04-27
# 6  Use of Diphenhydramine as an Adjunctive Sedati...  NCT01967433 2020-01-01
#
#                                 journal
# 1          Journal of emergency nursing
# 2          Journal of emergency nursing
# 3          Journal of emergency nursing
# 4     Hôpitaux Universitaires de Genève
# 5  Journal of emergency nursing\xc3\x28
# 6          Journal of emergency nursing

# %%
clinical_trials_final_df['date'] = clinical_trials_final_df['date'].dt.strftime('%Y-%m-%d')

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Construction du graphe de liaison

# %%
drugs_df
# Out:
#    atccode             drug
# 0    A04AD  DIPHENHYDRAMINE
# 1    S03AA     TETRACYCLINE
# 2    V03AB          ETHANOL
# 3    A03BA         ATROPINE
# 4    A01AD      EPINEPHRINE
# 5  6302001     ISOPRENALINE
# 6    R01AD    BETAMETHASONE

# %%
pubmed_final_df
# Out:
#     id                                              title        date  \
# 0    1  A 44-year-old man with erythema of the face di...  2019-01-01
# 1    2  An evaluation of benadryl, pyribenzamine, and ...  2019-01-01
# 2    3  Diphenhydramine hydrochloride helps symptoms o...  2019-02-01
# 3    4  Tetracycline Resistance Patterns of Lactobacil...  2020-01-01
# 4    5  Appositional Tetracycline bone formation rates...  2020-02-01
# 5    6  Rapid reacquisition of contextual fear followi...  2020-01-01
# 6    7  The High Cost of Epinephrine Autoinjectors and...  2020-01-02
# 7    8  Time to epinephrine treatment is associated wi...  2020-01-03
# 8    9  Gold nanoparticles synthesized from Euphorbia ...  2020-01-01
# 9   10  Clinical implications of umbilical artery Dopp...  2020-01-01
# 10  11  Effects of Topical Application of Betamethason...  2020-01-01
# 11  12  Comparison of pressure release, phonophoresis ...  2020-01-03
# 12  13  Comparison of pressure BETAMETHASONE release, ...  2020-01-03
#
#                                               journal
# 0                        Journal of emergency nursing
# 1                        Journal of emergency nursing
# 2                           The Journal of pediatrics
# 3                          Journal of food protection
# 4             American journal of veterinary research
# 5                                  Psychopharmacology
# 6   The journal of allergy and clinical immunology...
# 7   The journal of allergy and clinical immunology...
# 8   Journal of photochemistry and photobiology. B,...
# 9   The journal of maternal-fetal & neonatal medicine
# 10  Journal of back and musculoskeletal rehabilita...
# 11  Journal of back and musculoskeletal rehabilita...
# 12  The journal of maternal-fetal & neonatal medicine

# %%
list_pubmed = []

for index, value in drugs_df['drug'].items():
    temp_list = []
    for index2, value2 in pubmed_final_df['title'].items():
        if drugs_df['drug'][index].lower() in value2.lower():
            temp_list.append(pubmed_final_df.iloc[index2].to_dict())
    list_pubmed.append(temp_list)

list_pubmed
# Out:
# [[{'id': 1,
#    'title': 'A 44-year-old man with erythema of the face diphenhydramine, neck, and chest, weakness, and palpitations',
#    'date': '2019-01-01',
#    'journal': 'Journal of emergency nursing'},
#   {'id': 2,
#    'title': 'An evaluation of benadryl, pyribenzamine, and other so-called diphenhydramine antihistaminic drugs in the treatment of allergy.',
#    'date': '2019-01-01',
#    'journal': 'Journal of emergency nursing'},
#   {'id': 3,
#    'title': 'Diphenhydramine hydrochloride helps symptoms of ciguatera fish poisoning.',
#    'date': '2019-02-01',
#    'journal': 'The Journal of pediatrics'}],
#  [{'id': 4,
#    'title': 'Tetracycline Resistance Patterns of Lactobacillus buchneri Group Strains.',
#    'date': '2020-01-01',
#    'journal': 'Journal of food protection'},
#   {'id': 5,
#    'title': 'Appositional Tetracycline bone formation rates in the Beagle.',
#    'date': '2020-02-01',
#    'journal': 'American journal of veterinary research'},
#   {'id': 6,
#    'title': 'Rapid reacquisition of contextual fear following extinction in mice: effects of amount of extinction, tetracycline acute ethanol withdrawal, and ethanol intoxication.',
#    'date': '2020-01-01',
#    'journal': 'Psychopharmacology'}],
#  [{'id': 6,
#    'title': 'Rapid reacquisition of contextual fear following extinction in mice: effects of amount of extinction, tetracycline acute ethanol withdrawal, and ethanol intoxication.',
#    'date': '2020-01-01',
#    'journal': 'Psychopharmacology'}],
#  [{'id': 13,
#    'title': 'Comparison of pressure BETAMETHASONE release, phonophoresis and dry needling in treatment of latent myofascial trigger point of upper trapezius ATROPINE muscle.',
#    'date': '2020-01-03',
#    'journal': 'The journal of maternal-fetal & neonatal medicine'}],
#  [{'id': 7,
#    'title': 'The High Cost of Epinephrine Autoinjectors and Possible Alternatives.',
#    'date': '2020-01-02',
#    'journal': 'The journal of allergy and clinical immunology. In practice'},
#   {'id': 8,
#    'title': 'Time to epinephrine treatment is associated with the risk of mortality in children who achieve sustained ROSC after traumatic out-of-hospital cardiac arrest.',
#    'date': '2020-01-03',
#    'journal': 'The journal of allergy and clinical immunology. In practice'}],
#  [{'id': 9,
#    'title': 'Gold nanoparticles synthesized from Euphorbia fischeriana root by green route method alleviates the isoprenaline hydrochloride induced myocardial infarction in rats.',
#    'date': '2020-01-01',
#    'journal': 'Journal of photochemistry and photobiology. B, Biology'}],
#  [{'id': 10,
#    'title': 'Clinical implications of umbilical artery Doppler changes after betamethasone administration',
#    'date': '2020-01-01',
#    'journal': 'The journal of maternal-fetal & neonatal medicine'},
#   {'id': 11,
#    'title': 'Effects of Topical Application of Betamethasone on Imiquimod-induced Psoriasis-like Skin Inflammation in Mice.',
#    'date': '2020-01-01',
#    'journal': 'Journal of back and musculoskeletal rehabilitation'},
#   {'id': 13,
#    'title': 'Comparison of pressure BETAMETHASONE release, phonophoresis and dry needling in treatment of latent myofascial trigger point of upper trapezius ATROPINE muscle.',
#    'date': '2020-01-03',
#    'journal': 'The journal of maternal-fetal & neonatal medicine'}]]

# %%
drugs_df['pubmeds'] = list_pubmed

# %%
drugs_df
# Out:
#    atccode             drug                                            pubmeds
# 0    A04AD  DIPHENHYDRAMINE  [{'id': 1, 'title': 'A 44-year-old man with er...
# 1    S03AA     TETRACYCLINE  [{'id': 4, 'title': 'Tetracycline Resistance P...
# 2    V03AB          ETHANOL  [{'id': 6, 'title': 'Rapid reacquisition of co...
# 3    A03BA         ATROPINE  [{'id': 13, 'title': 'Comparison of pressure B...
# 4    A01AD      EPINEPHRINE  [{'id': 7, 'title': 'The High Cost of Epinephr...
# 5  6302001     ISOPRENALINE  [{'id': 9, 'title': 'Gold nanoparticles synthe...
# 6    R01AD    BETAMETHASONE  [{'id': 10, 'title': 'Clinical implications of...

# %%
clinical_trials_final_df
# Out:
#                                     scientific_title           id        date  \
# 1  Feasibility of a Randomized Controlled Clinica...  NCT04237091  2020-01-01
# 2  Glucagon Infusion in T1D Patients With Recurre...  NCT03490942  2020-05-25
# 3  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...  NCT04189588  2020-01-01
# 4  Preemptive Infiltration With Betamethasone and...  NCT04153396  2020-01-01
# 5  Tranexamic Acid Versus Epinephrine During Expl...  NCT04188184  2020-04-27
# 6  Use of Diphenhydramine as an Adjunctive Sedati...  NCT01967433  2020-01-01
#
#                                 journal
# 1          Journal of emergency nursing
# 2          Journal of emergency nursing
# 3          Journal of emergency nursing
# 4     Hôpitaux Universitaires de Genève
# 5  Journal of emergency nursing\xc3\x28
# 6          Journal of emergency nursing

# %% [markdown]
# ---

# %%
list_ctrials = []

for index, value in drugs_df['drug'].items():
    temp_list = []
    for index2, value2 in clinical_trials_final_df['scientific_title'].items():
        if drugs_df['drug'][index].lower() in value2.lower():
            temp_list.append(pubmed_final_df.iloc[index2].to_dict())
    list_ctrials.append(temp_list)

list_ctrials
# Out:
# [[{'id': 2,
#    'title': 'An evaluation of benadryl, pyribenzamine, and other so-called diphenhydramine antihistaminic drugs in the treatment of allergy.',
#    'date': '2019-01-01',
#    'journal': 'Journal of emergency nursing'},
#   {'id': 4,
#    'title': 'Tetracycline Resistance Patterns of Lactobacillus buchneri Group Strains.',
#    'date': '2020-01-01',
#    'journal': 'Journal of food protection'},
#   {'id': 7,
#    'title': 'The High Cost of Epinephrine Autoinjectors and Possible Alternatives.',
#    'date': '2020-01-02',
#    'journal': 'The journal of allergy and clinical immunology. In practice'}],
#  [],
#  [],
#  [],
#  [{'id': 6,
#    'title': 'Rapid reacquisition of contextual fear following extinction in mice: effects of amount of extinction, tetracycline acute ethanol withdrawal, and ethanol intoxication.',
#    'date': '2020-01-01',
#    'journal': 'Psychopharmacology'}],
#  [],
#  [{'id': 5,
#    'title': 'Appositional Tetracycline bone formation rates in the Beagle.',
#    'date': '2020-02-01',
#    'journal': 'American journal of veterinary research'}]]

# %%
drugs_df['clinical_trials'] = list_ctrials

# %%
drugs_df
# Out:
#    atccode             drug  \
# 0    A04AD  DIPHENHYDRAMINE
# 1    S03AA     TETRACYCLINE
# 2    V03AB          ETHANOL
# 3    A03BA         ATROPINE
# 4    A01AD      EPINEPHRINE
# 5  6302001     ISOPRENALINE
# 6    R01AD    BETAMETHASONE
#
#                                              pubmeds  \
# 0  [{'id': 1, 'title': 'A 44-year-old man with er...
# 1  [{'id': 4, 'title': 'Tetracycline Resistance P...
# 2  [{'id': 6, 'title': 'Rapid reacquisition of co...
# 3  [{'id': 13, 'title': 'Comparison of pressure B...
# 4  [{'id': 7, 'title': 'The High Cost of Epinephr...
# 5  [{'id': 9, 'title': 'Gold nanoparticles synthe...
# 6  [{'id': 10, 'title': 'Clinical implications of...
#
#                                      clinical_trials
# 0  [{'id': 2, 'title': 'An evaluation of benadryl...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'id': 6, 'title': 'Rapid reacquisition of co...
# 5                                                 []
# 6  [{'id': 5, 'title': 'Appositional Tetracycline...

# %%
drugs_df.to_json('final.json', orient='records')
